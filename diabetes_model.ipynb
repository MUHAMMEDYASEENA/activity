# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data=pd.read_csv(r'C:\Users\welcome\Downloads\diabetes_model.csv')
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              5       77             82             41       42  35.8
# 1              9      122             56              0        0  33.3
# 2              0      113             76              0        0  33.3
# 3              1      139             62             41      480  40.7
# 4             10      161             68             23      132  25.5
# ..           ...      ...            ...            ...      ...   ...
# 609            4      114             64              0        0  28.9
# 610            2      175             88              0        0  22.9
# 611            3      121             52              0        0  36.0
# 612            7      136             74             26      135  26.0
# 613            4      156             75              0        0  48.3
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.156   35        0
# ...

# %% [markdown]
# # Count plot of Outcome

# %%
sns.countplot(data['Outcome'])
# Out:
# C:\Users\welcome\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Outcome', ylabel='count'>

# %% [markdown]
# # Analyse effect of age on Outcome using Boxplot

# %%
sns.boxplot(x="Outcome",y="Age",data=data)
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='Age'>

# %% [markdown]
# # Check for the chances of getting diabetes if it is common in family, using the Diabetes Pedigree Function

# %%
sns.swarmplot(y=data['DiabetesPedigreeFunction'],x=data['Outcome'],data=data)
# Out:
# C:\Users\welcome\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 23.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Outcome', ylabel='DiabetesPedigreeFunction'>

# %% [markdown]
# # Check for the relationship with Insulin & Glucose and group the datapoints by Outcome

# %%
plt.figure(figsize=(8,8))
sns.stripplot(x=data['Insulin'],y=data['Glucose'],data=data,hue=data['Outcome'])
# Out:
# <AxesSubplot:xlabel='Insulin', ylabel='Glucose'>

# %% [markdown]
# # Create a heatmap on Correlation of features in the data

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>
